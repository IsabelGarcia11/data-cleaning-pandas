# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import re

# %%
attacks2 = pd.read_csv("../DATA/attacks.csv",encoding="ISO-8859–1")
attacks2
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
attacks=attacks2.copy()
attacks
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
columns=attacks.keys()
print(columns)
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
col1=[items.replace(" ","_").lower() for items in columns]
print(col1)
# Out:
# ['case_number', 'date', 'year', 'type', 'country', 'area', 'location', 'activity', 'name', 'sex_', 'age', 'injury', 'fatal_(y/n)', 'time', 'species_', 'investigator_or_source', 'pdf', 'href_formula', 'href', 'case_number.1', 'case_number.2', 'original_order', 'unnamed:_22', 'unnamed:_23']

# %%
col2=[items.replace(":","") for items in col1]
print(col2)
# Out:
# ['case_number', 'date', 'year', 'type', 'country', 'area', 'location', 'activity', 'name', 'sex_', 'age', 'injury', 'fatal_(y/n)', 'time', 'species_', 'investigator_or_source', 'pdf', 'href_formula', 'href', 'case_number.1', 'case_number.2', 'original_order', 'unnamed_22', 'unnamed_23']

# %%
col=[items.replace(".","") for items in col2]
print(col)
# Out:
# ['case_number', 'date', 'year', 'type', 'country', 'area', 'location', 'activity', 'name', 'sex_', 'age', 'injury', 'fatal_(y/n)', 'time', 'species_', 'investigator_or_source', 'pdf', 'href_formula', 'href', 'case_number1', 'case_number2', 'original_order', 'unnamed_22', 'unnamed_23']

# %%
attacks=attacks.set_axis(col,axis=1)
at=attacks.copy()
display(at)
# Out:
#       case_number         date    year        type    country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   area                        location     activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
total_null=at.isnull().sum()
total_null
# Out:
# case_number               17021
# date                      19421
# year                      19423
# type                      19425
# country                   19471
# area                      19876
# location                  19961
# activity                  19965
# name                      19631
# sex_                      19986
# age                       22252
# injury                    19449
# fatal_(y/n)               19960
# time                      22775
# species_                  22259
# investigator_or_source    19438
# pdf                       19421
# href_formula              19422
# href                      19421
# case_number1              19421
# case_number2              19421
# original_order            19414
# unnamed_22                25722
# unnamed_23                25721
# dtype: int64

# %%
at.shape
# Out:
# (25723, 24)

# %%
at.head(5)
# Out:
#   case_number         date    year        type    country             area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          location     activity             name sex_  ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
at.tail(5)
# Out:
#       case_number date  year type country area location activity name sex_  \
# 25718         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25719         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25720         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25721         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25722          xx  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        ... species_ investigator_or_source  pdf href_formula href  \
# 25718  ...      NaN                    NaN  NaN          NaN  NaN
# 25719  ...      NaN                    NaN  NaN          NaN  NaN
# 25720  ...      NaN                    NaN  NaN          NaN  NaN
# 25721  ...      NaN                    NaN  NaN          NaN  NaN
# 25722  ...      NaN                    NaN  NaN          NaN  NaN
#
#       case_number1 case_number2 original_order unnamed_22 unnamed_23
# ...

# %%
at.sample(frac=0.1)
# Out:
#       case_number         date    year        type    country  \
# 22423         NaN          NaN     NaN         NaN        NaN
# 7087            0          NaN     NaN         NaN        NaN
# 19783         NaN          NaN     NaN         NaN        NaN
# 22074         NaN          NaN     NaN         NaN        NaN
# 7324            0          NaN     NaN         NaN        NaN
# ...           ...          ...     ...         ...        ...
# 17796         NaN          NaN     NaN         NaN        NaN
# 7589            0          NaN     NaN         NaN        NaN
# 24182         NaN          NaN     NaN         NaN        NaN
# 40     2018.02.23  23-Feb-2018  2018.0  Unprovoked  AUSTRALIA
# 4851   1937.05.15  15-May-1937  1937.0  Unprovoked  AUSTRALIA
#
#                   area                            location  \
# 22423              NaN                                 NaN
# 7087               NaN                                 NaN
# ...

# %%
at.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   case_number             8702 non-null   object
#  1   date                    6302 non-null   object
#  2   year                    6300 non-null   float64
#  3   type                    6298 non-null   object
#  4   country                 6252 non-null   object
#  5   area                    5847 non-null   object
#  6   location                5762 non-null   object
#  7   activity                5758 non-null   object
#  8   name                    6092 non-null   object
#  9   sex_                    5737 non-null   object
#  10  age                     3471 non-null   object
#  11  injury                  6274 non-null   object
#  12  fatal_(y/n)             5763 non-null   object
#  13  time                    2948 non-null   object
# ...

# %%
at.describe().T
# Out:
#                  count         mean          std  min     25%     50%     75%  \
# year            6300.0  1927.272381   281.116308  0.0  1942.0  1977.0  2005.0
# original_order  6309.0  3155.999683  1821.396206  2.0  1579.0  3156.0  4733.0
#
#                    max
# year            2018.0
# original_order  6310.0

# %%
at.area.value_counts()
# Out:
# Florida                                 1037
# New South Wales                          486
# Queensland                               311
# Hawaii                                   298
# California                               290
#                                         ...
# Ysabel Island                              1
#  Lau Province                              1
# South Coast, East New Britain              1
# Between Southampton & Canary Islands       1
# Moala Island                               1
# Name: area, Length: 825, dtype: int64

# %%
numericas = at._get_numeric_data()
numericas.head()
# Out:
#      year  original_order
# 0  2018.0          6303.0
# 1  2018.0          6302.0
# 2  2018.0          6301.0
# 3  2018.0          6300.0
# 4  2018.0          6299.0

# %%
at[["href","href_formula"]]
# Out:
#                                                     href  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 25718                                                NaN
# 25719                                                NaN
# 25720                                                NaN
# 25721                                                NaN
# 25722                                                NaN
#
#                                             href_formula
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...

# %%
#sacamos los valores únicos de cada columna

# %%
at.head(1)
# Out:
#   case_number         date    year     type country        area  \
# 0  2018.06.25  25-Jun-2018  2018.0  Boating     USA  California
#
#                       location  activity         name sex_  ...     species_  \
# 0  Oceanside, San Diego County  Paddling  Julie Wolfe    F  ...  White shark
#
#   investigator_or_source                   pdf  \
# 0       R. Collier, GSAF  2018.06.25-Wolfe.pdf
#
#                                         href_formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href case_number1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...   2018.06.25
#
#   case_number2 original_order unnamed_22 unnamed_23
# 0   2018.06.25         6303.0        NaN        NaN
#
# [1 rows x 24 columns]

# %%
print(at.year.unique())
# Out:
# [2018. 2017.   nan 2016. 2015. 2014. 2013. 2012. 2011. 2010. 2009. 2008.
#  2007. 2006. 2005. 2004. 2003. 2002. 2001. 2000. 1999. 1998. 1997. 1996.
#  1995. 1984. 1994. 1993. 1992. 1991. 1990. 1989. 1969. 1988. 1987. 1986.
#  1985. 1983. 1982. 1981. 1980. 1979. 1978. 1977. 1976. 1975. 1974. 1973.
#  1972. 1971. 1970. 1968. 1967. 1966. 1965. 1964. 1963. 1962. 1961. 1960.
#  1959. 1958. 1957. 1956. 1955. 1954. 1953. 1952. 1951. 1950. 1949. 1948.
#  1848. 1947. 1946. 1945. 1944. 1943. 1942. 1941. 1940. 1939. 1938. 1937.
#  1936. 1935. 1934. 1933. 1932. 1931. 1930. 1929. 1928. 1927. 1926. 1925.
#  1924. 1923. 1922. 1921. 1920. 1919. 1918. 1917. 1916. 1915. 1914. 1913.
#  1912. 1911. 1910. 1909. 1908. 1907. 1906. 1905. 1904. 1903. 1902. 1901.
#  1900. 1899. 1898. 1897. 1896. 1895. 1894. 1893. 1892. 1891. 1890. 1889.
#  1888. 1887. 1886. 1885. 1884. 1883. 1882. 1881. 1880. 1879. 1878. 1877.
#  1876. 1875. 1874. 1873. 1872. 1871. 1870. 1869. 1868. 1867. 1866. 1865.
# ...

# %%
print(at.type.unique())
# Out:
# ['Boating' 'Unprovoked' 'Invalid' 'Provoked' 'Questionable' 'Sea Disaster'
#  nan 'Boat' 'Boatomg']

# %%
print(at.country.unique())
# Out:
# ['USA' 'AUSTRALIA' 'MEXICO' 'BRAZIL' 'ENGLAND' 'SOUTH AFRICA' 'THAILAND'
#  'COSTA RICA' 'MALDIVES' 'BAHAMAS' 'NEW CALEDONIA' 'ECUADOR' 'MALAYSIA'
#  'LIBYA' nan 'CUBA' 'MAURITIUS' 'NEW ZEALAND' 'SPAIN' 'SAMOA'
#  'SOLOMON ISLANDS' 'JAPAN' 'EGYPT' 'ST HELENA, British overseas territory'
#  'COMOROS' 'REUNION' 'FRENCH POLYNESIA' 'UNITED KINGDOM'
#  'UNITED ARAB EMIRATES' 'PHILIPPINES' 'INDONESIA' 'CHINA' 'COLUMBIA'
#  'CAPE VERDE' 'Fiji' 'DOMINICAN REPUBLIC' 'CAYMAN ISLANDS' 'ARUBA'
#  'MOZAMBIQUE' 'FIJI' 'PUERTO RICO' 'ITALY' 'ATLANTIC OCEAN' 'GREECE'
#  'ST. MARTIN' 'FRANCE' 'PAPUA NEW GUINEA' 'TRINIDAD & TOBAGO' 'KIRIBATI'
#  'ISRAEL' 'DIEGO GARCIA' 'TAIWAN' 'JAMAICA' 'PALESTINIAN TERRITORIES'
#  'GUAM' 'SEYCHELLES' 'BELIZE' 'NIGERIA' 'TONGA' 'SCOTLAND' 'CANADA'
#  'CROATIA' 'SAUDI ARABIA' 'CHILE' 'ANTIGUA' 'KENYA' 'RUSSIA'
#  'TURKS & CAICOS' 'UNITED ARAB EMIRATES (UAE)' 'AZORES' 'SOUTH KOREA'
#  'MALTA' 'VIETNAM' 'MADAGASCAR' 'PANAMA' 'SOMALIA' 'NEVIS'
# ...

# %%
print(at.activity.unique())
# Out:
# ['Paddling' 'Standing' 'Surfing' ...
#  'Crew swimming alongside their anchored ship' '4 men were bathing'
#  'Wreck of  large double sailing canoe']

# %%
print(at.sex_.unique())
# Out:
# ['F' 'M' nan 'M ' 'lli' 'N' '.']

# %%
print(at.age.unique())
# Out:
# ['57' '11' '48' nan '18' '52' '15' '12' '32' '10' '21' '34' '30' '60' '33'
#  '29' '54' '41' '37' '56' '19' '25' '69' '38' '55' '35' '46' '45' '14'
#  '40s' '28' '20' '24' '26' '49' '22' '7' '31' '17' '40' '13' '42' '3' '8'
#  '50' '16' '82' '73' '20s' '68' '51' '39' '58' 'Teen' '47' '61' '65' '36'
#  '66' '43' '60s' '9' '72' '59' '6' '27' '64' '23' '71' '44' '62' '63' '70'
#  '18 months' '53' '30s' '50s' 'teen' '77' '74' '28 & 26' '5' '86'
#  '18 or 20' '12 or 13' '46 & 34' '28, 23 & 30' 'Teens' '36 & 26' '8 or 10'
#  '84' '\xa0 ' ' ' '30 or 36' '6½' '21 & ?' '75' '33 or 37' 'mid-30s'
#  '23 & 20' ' 30' '7      &    31' ' 28' '20?' "60's" '32 & 30' '16 to 18'
#  '87' '67' 'Elderly' 'mid-20s' 'Ca. 33' '74 ' '45 ' '21 or 26' '20 ' '>50'
#  '18 to 22' 'adult' '9 & 12' '? & 19' '9 months' '25 to 35' '23 & 26' '1'
#  '(adult)' '33 & 37' '25 or 28' '37, 67, 35, 27,  ? & 27' '21, 34,24 & 35'
#  '30 & 32' '50 & 30' '17 & 35' 'X' '"middle-age"' '13 or 18' '34 & 19'
# ...

# %%
print(at.injury.unique())
# Out:
# ['No injury to occupant, outrigger canoe and paddle damaged'
#  'Minor injury to left thigh'
#  'Injury to left lower leg from surfboard skeg' ...
#  'FATAL, leg stripped of flesh  '
#  'FATAL, knocked overboard by tail of shark & carried off by shark '
#  'FATAL. "Shark bit him in half, carrying away the lower extremities" ']

# %%
print(at.fatal_.unique())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-2e1ed9ed4c17> in <module>
# ----> 1 print(at.fatal_.unique())
#
# ~/anaconda3/envs/ironhack/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'fatal_'

# %%
print(at.time.unique())
# Out:
# ['18h00' '14h00  -15h00' '07h45' nan 'Late afternoon' '17h00' '14h00'
#  'Morning' '15h00' '08h15' '11h00' '10h30' '10h40' '16h50' '07h00' '09h30'
#  'Afternoon' '21h50' '09h40' '08h00' '17h35' '15h30' '07h30' '19h00, Dusk'
#  'Night' '16h00' '15h01' '12h00' '13h45' '23h30' '09h00' '14h30' '18h30'
#  '12h30' '16h30' '18h45' '06h00' '10h00' '10h44' '13h19' 'Midday' '13h30'
#  '10h45' '11h20' '11h45' '19h30' '08h30' '15h45' 'Shortly before 12h00'
#  '17h34' '17h10' '11h15' '08h50' '17h45' '13h00' '10h20' '13h20' '02h00'
#  '09h50' '11h30' '17h30' '9h00' '10h43' 'After noon' '15h15' '15h40'
#  '19h05' '1300' '14h30 / 15h30' '22h00' '16h20' '14h34' '15h25' '14h55'
#  '17h46' 'Morning ' '15h49' '19h00' 'Midnight' '09h30 / 10h00' '10h15'
#  '18h15' '04h00' '14h50' '13h50' '19h20' '10h25' '10h45-11h15' '16h45'
#  '15h52' '06h15' '14h40' '19h45' '10h10' '08h45' 'Evening' '12h10' '18h05'
#  '11h41' '12h25' '17h51' '16h12' '12h45' '10h50' '14h15' '09h45' '06h45'
# ...

# %%
print(at.species_.unique())
# Out:
# ['White shark' nan '2 m shark' ... "12' tiger shark" 'Blue pointers'
#  'Said to involve a grey nurse shark that leapt out of the water and  seized the boy but species identification is questionable']

# %%
print(at.case_number1.unique())
# Out:
# ['2018.06.25' '2018.06.18' '2018.06.09' ... 'ND.0002' 'ND.0001' nan]

# %%
print(at.unnamed_22.unique())
# Out:
# [nan 'stopped here']

# %%
print(at.unnamed_23.unique())
# Out:
# [nan 'Teramo' 'change filename']

# %%
#mirar si ponemos fecha como indice

# %%
at.sort_values(by="year",ascending=False).head(5) #Ascending FALSE de mayor a menor , se debe guardar en variableluego calculos
# Out:
#      case_number                  date    year        type    country  \
# 0     2018.06.25           25-Jun-2018  2018.0     Boating        USA
# 40    2018.02.23           23-Feb-2018  2018.0  Unprovoked  AUSTRALIA
# 29  2018.04.15.a           15-Apr-2018  2018.0  Unprovoked  AUSTRALIA
# 30    2018.04.14           14-Apr-2018  2018.0  Unprovoked    BAHAMAS
# 31  2018.04.10.R  Reported 10-Apr-2018  2018.0     Invalid     BRAZIL
#
#                  area                            location  activity  \
# 0          California         Oceanside, San Diego County  Paddling
# 40    New South Wales  Little Congwong Beach, La Perouse   Swimming
# 29  Western Australia   Cobblestones, Margaret River Area   Surfing
# 30     New Providence                       Nirvana Beach   Surfing
# 31            Alagoas           Praia de Sauaçuhy, Maceió   Fishing
#
#                     name sex_  ...                             species_  \
# ...

# %%
at.sort_values(by=["year", "country"]).head()
# Out:
#      case_number         date  year        type    country           area  \
# 6291     ND.0011  Before 1911   0.0  Unprovoked      ASIA?            NaN
# 6189     ND-0139    1880-1899   0.0  Unprovoked  AUSTRALIA     Queensland
# 6190     ND-0138  Before 1909   0.0  Unprovoked  AUSTRALIA     Queensland
# 6204     ND-0116  Before 1936   0.0  Unprovoked  AUSTRALIA            NaN
# 6214     ND.0104        1950s   0.0  Unprovoked  AUSTRALIA  Torres Strait
#
#          location             activity               name sex_  ...  \
# 6291          NaN             Swimming         Mr. Masury    M  ...
# 6189    Boonooroo                  NaN             Lassie    F  ...
# 6190  Moreton Bay  Fell into the water  Lieutenant Hexton    M  ...
# 6204          NaN          Net-fishing    August Eichmann    M  ...
# 6214          NaN        Helmet diving               male    M  ...
#
#          species_                             investigator_or_source  \
# ...

# %%
at2=at.dropna(how="all", axis=0)
at2
# Out:
#       case_number         date    year        type    country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 8698            0          NaN     NaN         NaN        NaN
# 8699            0          NaN     NaN         NaN        NaN
# 8700            0          NaN     NaN         NaN        NaN
# 8701            0          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   area                        location     activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
print(at2.unnamed_22.unique())
# Out:
# [nan 'stopped here']
